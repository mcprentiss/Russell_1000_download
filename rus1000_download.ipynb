# %% [markdown]
# # Automated downloading of the Russell 1000 stocks from Yahoo

# %%
"""  Take list of stock ticker names and download data"""
"""
lynx  -print -dump  http://ichart.yahoo.com/table.csv?s=TM\&a=0\&b=1\&c=2000\&d=2\&e=31\&f=2013 > TM.csv
"""

import csv # first we need import necessary lib:csv
import os

myfilepath="rus1000.csv"
i = 0 
with open(myfilepath, 'rb') as f:
    mycsv = csv.reader(f)
    for row in mycsv:
        i += 1
        print row[0], i
        os.system('lynx -print -dump http://ichart.yahoo.com/table.csv?s=' + row[0] + '\&a=0\&b=1\&c=2000\&d=12\&e=31\&f=2013 > data/' + row[0] + '.csv ')
#        os.system('sleep 1')

# %% [markdown]
# ## Load csv data into data frames

# %%
"""  Take list of stock ticker names and download data """
"""  Date,Open,High,Low,Close,Volume,Adj Close """

import csv # first we need import necessary lib:csv
import os
import pandas

myfilepath="rus1000.csv"

with open(myfilepath, 'rb') as f:
    mycsv = csv.reader(f)
    for row in mycsv:
        open("'data/" + row[0] + ".csv'",
# Out:
#  'data/AFL.csv'
#  'data/ATK.csv'
#  'data/AGCO.csv'
#  'data/ANV.csv'
#  'data/GAS.csv'
#  'data/ALSN.csv'
#  'data/AES.csv'
#  'data/MDRX.csv'
#  'data/AMCX.csv'
#  'data/ALL.csv'
#  'data/AOL.csv'
#  'data/ANR.csv'
#  'data/T.csv'
#  'data/ALTR.csv'
#  'data/AVX.csv'
#  'data/MO.csv'
#  'data/AMZN.csv'
#  'data/ABT.csv'
#  'data/AEE.csv'
#  'data/ANF.csv'
#  'data/ACC.csv'
#  'data/APKT.csv'
#  'data/AGNC.csv'
#  'data/ATVI.csv'
#  'data/ACAS.csv'
#  'data/ADBE.csv'
#  'data/AEP.csv'
#  'data/AAP.csv'
#  'data/AEO.csv'
#  'data/ACM.csv'
#  'data/AXP.csv'
#  'data/AMD.csv'
#  'data/AFG.csv'
#  'data/AET.csv'
#  'data/AIG.csv'
#  'data/AMG.csv'
#  'data/ANAT.csv'
#  'data/A.csv'
#  'data/AMT.csv'
#  'data/AL.csv'
#  'data/AWK.csv'
#  'data/APD.csv'
#  'data/ABC.csv'
#  'data/ARG.csv'
#  'data/AGP.csv'
#  'data/AKAM.csv'
#  'data/AMP.csv'
#  'data/ALB.csv'
#  'data/AME.csv'
#  'data/AA.csv'
#  'data/AMGN.csv'
#  'data/ALEX.csv'
#  'data/APH.csv'
#  'data/ALR.csv'
#  'data/ARE.csv'
# ...
